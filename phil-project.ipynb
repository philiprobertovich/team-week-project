# %%
import pandas as pd
import matplotlib.pyplot as plt

cost_of_living = pd.read_csv('data/cost-of-living.csv', header=0)

cost_of_living.head()
# Out:
#    No.      city      country  Meal  Meal_For_2  McDonalds_Meal  \
# 0    0     Delhi        India  4.90       22.04            4.28
# 1    1  Shanghai        China  5.59       40.51            5.59
# 2    2   Jakarta    Indonesia  2.54       22.25            3.50
# 3    3    Manila  Philippines  3.54       27.40            3.54
# 4    4     Seoul  South Korea  7.16       52.77            6.03
#
#    Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  Cappuccino  \
# 0                      1.84                       3.67        1.78
# 1                      1.12                       4.19        3.96
# 2                      2.02                       3.18        2.19
# 3                      1.24                       1.90        2.91
# 4                      3.02                       4.52        3.86
#
#    Coke/Pepsi  ...     x47      x48     x49      x50      x51       x52  \
# 0        0.48  ...   36.26   223.87  133.38   596.16   325.82   2619.46
# ...

# %%
cost_of_living.tail()
# Out:
#        No.                city    country   Meal  Meal_For_2  McDonalds_Meal  \
# 4869  4869        Peterborough  Australia    NaN         NaN             NaN
# 4870  4870          Georgetown  Australia    NaN         NaN             NaN
# 4871  4871  Ixtapa Zihuatanejo     Mexico   5.19       31.13           12.97
# 4872  4872             Iqaluit     Canada  29.78       74.61           13.77
# 4873  4873              Neiafu      Tonga    NaN       29.53           10.55
#
#       Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  Cappuccino  \
# 4869                       NaN                        NaN         NaN
# 4870                       NaN                        NaN         NaN
# 4871                      0.99                        NaN        1.82
# 4872                      6.70                       8.93        3.72
# 4873                     10.55                        NaN         NaN
#
#       Coke/Pepsi  ...     x47     x48     x49      x50      x51  x52  x53  \
# ...

# %%
cost_of_living.shape
# Out:
# (4874, 59)

# %%
#Dropping columns that I'm not going to use.
to_drop = ['x28', 'x29', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36', 'x37', 'x38', 'x39', 'x40', 'x41', 'x42', 'x43', 'x44', 'x45', 'x46', 'x47', 'x48', 'x49', 'x50', 'x51', 'x52', 'x53', 'x54', 'x55', 'data_quality']

cost_of_living.drop(to_drop, inplace=True, axis=1)

cost_of_living.head()
# Out:
#    No.      city      country  Meal  Meal_For_2  McDonalds_Meal  \
# 0    0     Delhi        India  4.90       22.04            4.28
# 1    1  Shanghai        China  5.59       40.51            5.59
# 2    2   Jakarta    Indonesia  2.54       22.25            3.50
# 3    3    Manila  Philippines  3.54       27.40            3.54
# 4    4     Seoul  South Korea  7.16       52.77            6.03
#
#    Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  Cappuccino  \
# 0                      1.84                       3.67        1.78
# 1                      1.12                       4.19        3.96
# 2                      2.02                       3.18        2.19
# 3                      1.24                       1.90        2.91
# 4                      3.02                       4.52        3.86
#
#    Coke/Pepsi  ...  Oranges  Tomato  Potato  Onion  Lettuce  \
# 0        0.48  ...     1.01    0.60    0.36   0.41     0.70
# ...

# %%
cost_of_living.duplicated()
cost_of_living.drop_duplicates()
# Out:
#        No.                city      country   Meal  Meal_For_2  \
# 0        0               Delhi        India   4.90       22.04
# 1        1            Shanghai        China   5.59       40.51
# 2        2             Jakarta    Indonesia   2.54       22.25
# 3        3              Manila  Philippines   3.54       27.40
# 4        4               Seoul  South Korea   7.16       52.77
# ...    ...                 ...          ...    ...         ...
# 4869  4869        Peterborough    Australia    NaN         NaN
# 4870  4870          Georgetown    Australia    NaN         NaN
# 4871  4871  Ixtapa Zihuatanejo       Mexico   5.19       31.13
# 4872  4872             Iqaluit       Canada  29.78       74.61
# 4873  4873              Neiafu        Tonga    NaN       29.53
#
#       McDonalds_Meal  Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# 0               4.28                      1.84                       3.67
# ...

# %%
cost_of_living.count()
# Out:
# No.                            4874
# city                           4874
# country                        4874
# Meal                           4449
# Meal_For_2                     4432
# McDonalds_Meal                 4552
# Domestic_Beer_Rest(0.5L)       4385
# Imported_Beer_Rest(0.33L)      4445
# Cappuccino                     4540
# Coke/Pepsi                     4438
# Water_Rest(0.33L)              4571
# Milk                           4494
# Bread                          4457
# Rice                           4538
# Eggs                           4369
# Cheese                         4393
# Chicken_Fillets                4318
# Beef                           4312
# Apple                          4509
# Bananas                        4499
# Oranges                        4439
# Tomato                         4410
# Potato                         4444
# Onion                          4447
# Lettuce                        4379
# Water_Market(1.5L)             4490
# ...

# %%
print(cost_of_living.shape)
cost_of_living.describe()
# Out:
# (4874, 30)
#                No.         Meal   Meal_For_2  McDonalds_Meal  \
# count  4874.000000  4449.000000  4432.000000     4552.000000
# mean   2436.500000    10.321643    43.213592        6.875426
# std    1407.146936     7.165507    25.365827        2.669017
# min       0.000000     0.450000     3.250000        1.060000
# 25%    1218.250000     4.310000    22.350000        4.910000
# 50%    2436.500000     9.830000    40.000000        6.960000
# 75%    3654.750000    15.000000    60.000000        8.500000
# max    4873.000000    56.980000   211.350000       21.810000
#
#        Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)   Cappuccino  \
# count               4385.000000                4445.000000  4540.000000
# mean                   3.376732                   3.937287     2.742822
# std                    2.080606                   2.088773     1.353734
# min                    0.320000                   0.310000     0.220000
# ...

# %%
cost_of_living.set_index(['city', 'country'], inplace=True)
cost_of_living
# Out:
#                                  No.   Meal  Meal_For_2  McDonalds_Meal  \
# city               country
# Delhi              India           0   4.90       22.04            4.28
# Shanghai           China           1   5.59       40.51            5.59
# Jakarta            Indonesia       2   2.54       22.25            3.50
# Manila             Philippines     3   3.54       27.40            3.54
# Seoul              South Korea     4   7.16       52.77            6.03
# ...                              ...    ...         ...             ...
# Peterborough       Australia    4869    NaN         NaN             NaN
# Georgetown         Australia    4870    NaN         NaN             NaN
# Ixtapa Zihuatanejo Mexico       4871   5.19       31.13           12.97
# Iqaluit            Canada       4872  29.78       74.61           13.77
# Neiafu             Tonga        4873    NaN       29.53           10.55
#
#                                 Domestic_Beer_Rest(0.5L)  \
# ...

# %%
# Find average of the meal column
meal_len = cost_of_living.Meal.count()
meal_sum = cost_of_living.Meal.sum()
meal_average = round(meal_sum/meal_len, 2)
print(meal_average)
# Out:
# 10.32

# %%
# Finding the max and min values in the Meal column
max_meal = cost_of_living.Meal.max()
min_meal = cost_of_living.Meal.min()
print(max_meal)
print(min_meal)
# Out:
# 56.98
# 0.45

# %%
# Filtering the Meal column to find the row with the max value
cost_of_living[cost_of_living['Meal'] == 56.98]
# Out:
#                            No.   Meal  Meal_For_2  McDonalds_Meal  \
# city        country
# Turkmenabat Turkmenistan  1016  56.98      113.96             NaN
# Dasoguz     Turkmenistan  1540  56.98      170.94             NaN
#
#                           Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city        country
# Turkmenabat Turkmenistan                      5.70                      14.25
# Dasoguz     Turkmenistan                     14.25                        NaN
#
#                           Cappuccino  Coke/Pepsi  Water_Rest(0.33L)  Milk  \
# city        country
# Turkmenabat Turkmenistan        7.12         NaN               0.85  4.27
# Dasoguz     Turkmenistan        5.70        7.12                NaN  2.85
#
#                           ...  Oranges  Tomato  Potato  Onion  Lettuce  \
# city        country       ...
# Turkmenabat Turkmenistan  ...     6.27    1.99    1.14   0.85      NaN
# ...

# %%
# Filtering the Meal column to find the row with the min value
cost_of_living[cost_of_living['Meal'] == 0.45]
# Out:
#                     No.  Meal  Meal_For_2  McDonalds_Meal  \
# city     country
# Sargodha Pakistan   712  0.45       17.82            3.56
# Mardan   Pakistan  1251  0.45         NaN            4.46
#
#                    Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city     country
# Sargodha Pakistan                      2.45                       4.01
# Mardan   Pakistan                      2.45                       6.68
#
#                    Cappuccino  Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  \
# city     country                                                    ...
# Sargodha Pakistan        0.67        0.16               0.11  0.45  ...
# Mardan   Pakistan        0.67        0.16               0.11  0.45  ...
#
#                    Oranges  Tomato  Potato  Onion  Lettuce  \
# city     country
# Sargodha Pakistan     0.42    0.67    0.26   0.22     0.27
# Mardan   Pakistan     0.42    0.62    0.26   0.22     0.13
#
# ...

# %%
# Sorting Meal column to find top 5 least expensive places
cost_of_living.Meal.sort_values().head(5)
# Out:
# city        country
# Sargodha    Pakistan    0.45
# Mardan      Pakistan    0.45
# Shekhupura  Pakistan    0.53
# Bhavnagar   India       0.61
# Erode       India       0.61
# Name: Meal, dtype: float64

# %%
bottom_5_meal_values = [0.45, 0.45, 0.53, 0.61, 0.61]
bottom_5_meal_location = ['Sargodha, Pakistan', 'Mardan, Pakistan', 'Shekhpura, Pakistan', 'Bhavnagar, India', 'Erode, India']

# %%
# Create bar graph
plt.style.use('dark_background')

plt.title('Top 5 Least Expensive Meals Worldwide')

bar_width = 0.7

plt.bar(bottom_5_meal_location, bottom_5_meal_values, width=bar_width)
plt.bar('Average', meal_average, width=bar_width)
plt.xticks(rotation=45)
 

plt.xlabel('Country')
plt.ylabel('Price in USD')

plt.show()

# %%
# Sorting Meal column to find top 5 most expensive places
cost_of_living.Meal.sort_values(ascending=False).head(5)
# Out:
# city         country
# Dasoguz      Turkmenistan     56.98
# Turkmenabat  Turkmenistan     56.98
# Lorain       United States    55.00
# Cranford     United States    50.00
# Summit       United States    50.00
# Name: Meal, dtype: float64

# %%
top_5_meal_values = [56.98, 56.98, 55.00, 50.00, 50.00]
top_5_meal_locations = ['Dasoguz, Turkmenistan', ' Turkmenabat, Turkmenistan', 'Lorain, United States', 'Cranford, United States', 'Summit,United States']

# %%
# Create bar graph
plt.style.use('dark_background')

plt.title('Top 5 Most Expensive Meals Worldwide')

bar_width = 0.7

plt.bar(top_5_meal_locations, top_5_meal_values, width=bar_width)
plt.bar('Average', meal_average, width=bar_width)
plt.xticks(rotation=45)
 

plt.xlabel('Country')
plt.ylabel('Price in USD')

plt.show()

# %%
# Find max and min values for meal for 2 column
max_meal_for_2 = cost_of_living.Meal_For_2.max()
min_meal_for_2 = cost_of_living.Meal_For_2.min()
print(max_meal_for_2)
print(min_meal_for_2)
# Out:
# 211.35
# 3.25

# %%
#Filter to find max value in meal for 2 column
cost_of_living[cost_of_living.Meal_For_2 == 211.35]
# Out:
#                         No.   Meal  Meal_For_2  McDonalds_Meal  \
# city      country
# Mendrisio Switzerland  4621  25.89      211.35           15.85
#
#                        Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city      country
# Mendrisio Switzerland                      4.76                       5.02
#
#                        Cappuccino  Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  \
# city      country                                                       ...
# Mendrisio Switzerland        4.07        3.96               3.17  1.56  ...
#
#                        Oranges  Tomato  Potato  Onion  Lettuce  \
# city      country
# Mendrisio Switzerland      NaN    4.76    2.11   2.11      NaN
#
#                        Water_Market(1.5L)  Wine_Market  \
# city      country
# Mendrisio Switzerland                1.74        10.57
#
#                        Domestic_Beer_Market(0.5L)  \
# city      country
# Mendrisio Switzerland                         NaN
#
# ...

# %%
# Filter to find min value in meal for 2 column
cost_of_living[cost_of_living.Meal_For_2 == 3.25]
# Out:
#                          No.  Meal  Meal_For_2  McDonalds_Meal  \
# city         country
# Moratuwa     Sri Lanka  1632  1.36        3.25            1.98
# Nuwara Eliya Sri Lanka  3118  1.36        3.25             NaN
#
#                         Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city         country
# Moratuwa     Sri Lanka                      0.95                       1.08
# Nuwara Eliya Sri Lanka                      0.95                       1.08
#
#                         Cappuccino  Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  \
# city         country                                                     ...
# Moratuwa     Sri Lanka        0.27        0.19               0.14  0.73  ...
# Nuwara Eliya Sri Lanka         NaN        0.19               0.14  0.73  ...
#
#                         Oranges  Tomato  Potato  Onion  Lettuce  \
# city         country
# Moratuwa     Sri Lanka     1.63    0.49    0.47   0.43     0.62
# ...

# %%
# Sort meal for 2 column to find top 10 least expensive places
cost_of_living.Meal_For_2.sort_values().head(10)
# Out:
# city          country
# Moratuwa      Sri Lanka     3.25
# Nuwara Eliya  Sri Lanka     3.25
# Kurunegala    Sri Lanka     3.36
# Tangail       Bangladesh    3.75
# Negombo       Sri Lanka     4.07
# Tamale        Ghana         4.11
# Abbottabad    Pakistan      4.46
# Shekhupura    Pakistan      4.46
# Sahiwal       Pakistan      4.46
# Comilla       Bangladesh    4.68
# Name: Meal_For_2, dtype: float64

# %%
# Sort meal for 2 column to find 10 most expensive places
cost_of_living.Meal_For_2.sort_values(ascending=False).head(10)
# Out:
# city        country
# Mendrisio   Switzerland      211.35
# East Ridge  United States    175.00
# Dasoguz     Turkmenistan     170.94
# The Valley  Anguilla         170.00
# Ojai        United States    162.31
# Monaco      Monaco           155.80
# Hamilton    Bermuda          150.00
# Harrison    United States    150.00
# Or Yehuda   Israel           145.65
# Ashgabat    Turkmenistan     142.45
# Name: Meal_For_2, dtype: float64

# %%
# Find average of the McDonalds column
mcdonalds_len = cost_of_living.McDonalds_Meal.count()
mcdonalds_sum = cost_of_living.McDonalds_Meal.sum()
mcdonalds_average = round(mcdonalds_sum/mcdonalds_len, 2)
print(mcdonalds_average)
# Out:
# 6.88

# %%
# Find the min and max values in the McDonald's meal column
max_mcdonalds = cost_of_living.McDonalds_Meal.max()
min_mcdonalds = cost_of_living.McDonalds_Meal.min()
print(max_mcdonalds)
print(min_mcdonalds)
# Out:
# 21.81
# 1.06

# %%
# Filter to find the max value in the McDonalds column
cost_of_living[cost_of_living.McDonalds_Meal == 21.81]
# Out:
#                           No.   Meal  Meal_For_2  McDonalds_Meal  \
# city      country
# Pago Pago American Samoa  548  23.48        6.57           21.81
#
#                           Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city      country
# Pago Pago American Samoa                      1.88                       1.88
#
#                           Cappuccino  Coke/Pepsi  Water_Rest(0.33L)  Milk  \
# city      country
# Pago Pago American Samoa        0.99        1.17               2.08  1.04
#
#                           ...  Oranges  Tomato  Potato  Onion  Lettuce  \
# city      country         ...
# Pago Pago American Samoa  ...     3.12     NaN     NaN    NaN      NaN
#
#                           Water_Market(1.5L)  Wine_Market  \
# city      country
# Pago Pago American Samoa                 NaN          NaN
#
#                           Domestic_Beer_Market(0.5L)  \
# city      country
# Pago Pago American Samoa                         NaN
#
# ...

# %%
# Filter to find the min value in the McDonalds column
cost_of_living[cost_of_living.McDonalds_Meal == 1.06]
# Out:
#                        No.  Meal  Meal_For_2  McDonalds_Meal  \
# city     country
# Tacloban Philippines  1435  0.97        25.9            1.06
#
#                       Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city     country
# Tacloban Philippines                      0.62                       2.39
#
#                       Cappuccino  Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  \
# city     country                                                       ...
# Tacloban Philippines        2.48        0.35               0.22  1.41  ...
#
#                       Oranges  Tomato  Potato  Onion  Lettuce  \
# city     country
# Tacloban Philippines     1.06    1.41    1.65   1.06     1.06
#
#                       Water_Market(1.5L)  Wine_Market  \
# city     country
# Tacloban Philippines                0.52         6.72
#
#                       Domestic_Beer_Market(0.5L)  Imported_Beer_Market(0.33L)  \
# city     country
# ...

# %%
# Find the top 5 least expensive places for McDonalds Meal
cost_of_living['McDonalds_Meal'].sort_values().head(5)
# Out:
# city             country
# Tacloban         Philippines    1.06
# Tuguegarao       Philippines    1.33
# Sievierodonetsk  Ukraine        1.35
# Biskra           Algeria        1.44
# Ain Defla        Algeria        1.44
# Name: McDonalds_Meal, dtype: float64

# %%
mcdonalds_least_values = [1.06, 1.33, 1.35, 1.44, 1.44]
mcdonalds_least_locations = ['Tacloban, Philippines', 'Tuguegarao, Philippines', 'Sievierodonetsk, Ukraine', 'Biskra, Algeria', 'Ain Defla, Algeria']

# %%
# Create bar graph
plt.style.use('dark_background')

plt.title('Top 5 Least Expensive Mcdonalds Meals Worldwide')

bar_width = 0.7

plt.bar(mcdonalds_least_locations, mcdonalds_least_values, width=bar_width)
plt.bar('Average', mcdonalds_average, width=bar_width)
plt.xticks(rotation=45)
 

plt.xlabel('Country')
plt.ylabel('Price in USD')

plt.show()

# %%
# Find the top 5 most expensive places for McDonalds Meal
cost_of_living['McDonalds_Meal'].sort_values(ascending=False).head(5)
# Out:
# city       country
# Pago Pago  American Samoa       21.81
# Malabo     Equatorial Guinea    19.79
# Aigle      Switzerland          19.02
# Eilat      Israel               18.35
# Bat Yam    Israel               18.21
# Name: McDonalds_Meal, dtype: float64

# %%
mcdonalds_most_values = [21.81, 19.79, 19.02, 18.35, 18.21]
mcdonalds_most_locations = ['Pago Pago, American Somoa', 'Malabo, Equatorial Guinea', 'Aigle, Switzerland', 'Eilat, Israel', 'Bat Yam, Israel']

# %%
# Create bar graph
plt.style.use('dark_background')

plt.title('Top 5 Least Expensive Mcdonalds Meals Worldwide')

bar_width = 0.7

plt.bar(mcdonalds_most_locations, mcdonalds_most_values, width=bar_width)
plt.bar('Average', mcdonalds_average, width=bar_width)
plt.xticks(rotation=45)
 

plt.xlabel('Country')
plt.ylabel('Price in USD')

plt.show()

# %%
# Find average of cappuccino column
capp_len = cost_of_living.Cappuccino.count()
capp_sum = cost_of_living.Cappuccino.sum()
capp_average = round(capp_sum/capp_len, 2)
print(capp_average)
# Out:
# 2.67

# %%
# Find max and min value in the cappuccino column
max_capp = cost_of_living.Cappuccino.max()
min_capp = cost_of_living.Cappuccino.min()
print(max_capp)
print(min_capp)
# Out:
# 10.0
# 0.22

# %%
# Find max value in cappuccino column
cost_of_living[cost_of_living.Cappuccino == 10]
# Out:
#                        No.  Meal  Meal_For_2  McDonalds_Meal  \
# city   country
# Gallup United States  4457   NaN        60.0            15.0
#
#                       Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city   country
# Gallup United States                       NaN                        NaN
#
#                       Cappuccino  Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  \
# city   country                                                         ...
# Gallup United States        10.0         7.0                4.0  1.59  ...
#
#                       Oranges  Tomato  Potato  Onion  Lettuce  \
# city   country
# Gallup United States     6.61    6.61    5.51    NaN      1.5
#
#                       Water_Market(1.5L)  Wine_Market  \
# city   country
# Gallup United States                 NaN         13.0
#
#                       Domestic_Beer_Market(0.5L)  Imported_Beer_Market(0.33L)  \
# city   country
# ...

# %%
cost_of_living[cost_of_living.Cappuccino == 0.22]
# Out:
#                    No.  Meal  Meal_For_2  McDonalds_Meal  \
# city     country
# Medea    Algeria  2113  1.99       13.45            2.71
# Laghouat Algeria  2167  1.08       10.83            3.07
#
#                   Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city     country
# Medea    Algeria                      1.58                       1.76
# Laghouat Algeria                      1.62                       1.08
#
#                   Cappuccino  Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  \
# city     country                                                   ...
# Medea    Algeria        0.22        0.34               0.16  0.45  ...
# Laghouat Algeria        0.22        0.34               0.14  0.60  ...
#
#                   Oranges  Tomato  Potato  Onion  Lettuce  Water_Market(1.5L)  \
# city     country
# Medea    Algeria     0.58    0.29    0.36   0.11      NaN                0.22
# Laghouat Algeria     1.26    0.54    0.49   0.22     0.58                0.22
# ...

# %%
# Find the top 10 least expensive places that sell cappuccino
cost_of_living.Cappuccino.sort_values().head(10)
# Out:
# city                country
# Laghouat            Algeria      0.22
# Medea               Algeria      0.22
# Bordj Bou Arreridj  Algeria      0.23
# Mostaganem          Algeria      0.25
# Ratnapura           Sri Lanka    0.27
# Moratuwa            Sri Lanka    0.27
# Puttalam            Sri Lanka    0.27
# Batticaloa          Sri Lanka    0.27
# El Bayadh           Algeria      0.29
# Setif               Algeria      0.30
# Name: Cappuccino, dtype: float64

# %%
least_capp_values = [0.22, 0.22, 0.23, 0.25, 0.27]
least_capp_locations = ['Laghouat, Algeria', 'Medea, Algeria', 'Bordj Bou Arreridj, Algeria', 'Mostaganem, Algeria', 'Ratnapura, Sci Lanka']

# %%
# Create bar graph
plt.style.use('dark_background')

plt.title('Top 5 Least Expensive Cappuccinos Worldwide')

bar_width = 0.7

plt.bar(least_capp_locations, least_capp_values, width=bar_width)
plt.bar('Average', capp_average, width=bar_width)
plt.xticks(rotation=45)
 

plt.xlabel('Country')
plt.ylabel('Price in USD')

plt.show()

# %%
# Find the top 10 most expensive places that sell cappuccino
cost_of_living.Cappuccino.sort_values(ascending=False).head(10)
# Out:
# city          country
# Gallup        United States    10.00
# Plainedge     United States     8.00
# Perrysburg    United States     8.00
# Menominee     United States     8.00
# Topeka        United States     7.67
# Turkmenabat   Turkmenistan      7.12
# Commack       United States     7.00
# Spanish Fork  United States     7.00
# League City   United States     7.00
# Thomasville   United States     7.00
# Name: Cappuccino, dtype: float64

# %%
most_capp_values = [10.00, 8.00, 8.00, 8.00, 7.67]
most_capp_locations = ['Gallup, United States', 'Plainedge, United States', 'Perrysburg, United States', 'Menominee, United States', 'Topeka, United States']

# %%
# Create bar graph
plt.style.use('dark_background')

plt.title('Top 5 Most Expensive Cappuccinos Worldwide')

bar_width = 0.7

plt.bar(most_capp_locations, most_capp_values, width=bar_width)
plt.bar('Average', capp_average, width=bar_width)
plt.xticks(rotation=45)
 

plt.xlabel('Country')
plt.ylabel('Price in USD')

plt.show()

# %%
# Find average of milk column
milk_len = cost_of_living.Milk.count()
milk_sum = cost_of_living.Milk.sum()
milk_average = round(milk_sum/milk_len, 2)
print(milk_average)
# Out:
# 1.14

# %%
# Find max and min values of the Milk column
max_milk = cost_of_living.Milk.max()
min_milk = cost_of_living.Milk.min()
print(max_milk)
print(min_milk)
# Out:
# 6.81
# 0.26

# %%
# Find max Milk value in dataframe
cost_of_living[cost_of_living.Milk == 6.81]
# Out:
#                 No.  Meal  Meal_For_2  McDonalds_Meal  \
# city   country
# Beirut Lebanon  477  10.0        60.0             6.1
#
#                 Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city   country
# Beirut Lebanon                       3.0                       4.82
#
#                 Cappuccino  Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  Oranges  \
# city   country                                                   ...
# Beirut Lebanon        3.51        2.99               1.07  6.81  ...     1.38
#
#                 Tomato  Potato  Onion  Lettuce  Water_Market(1.5L)  \
# city   country
# Beirut Lebanon    1.81    1.53   1.01     0.83                0.61
#
#                 Wine_Market  Domestic_Beer_Market(0.5L)  \
# city   country
# Beirut Lebanon          7.0                        1.19
#
#                 Imported_Beer_Market(0.33L)  Cigarettes
# city   country
# Beirut Lebanon                         3.33        5.79
#
# [1 rows x 28 columns]

# %%
# Find min Milk value in dataframe
cost_of_living[cost_of_living.Milk == 0.26]
# Out:
#                        No.  Meal  Meal_For_2  McDonalds_Meal  \
# city      country
# Pyongyang North Korea  181  4.27       20.49            3.13
#
#                        Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city      country
# Pyongyang North Korea                       NaN                        NaN
#
#                        Cappuccino  Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  \
# city      country                                                       ...
# Pyongyang North Korea        1.81        1.68               1.99  0.26  ...
#
#                        Oranges  Tomato  Potato  Onion  Lettuce  \
# city      country
# Pyongyang North Korea      2.2     2.2     2.2    2.2      1.0
#
#                        Water_Market(1.5L)  Wine_Market  \
# city      country
# Pyongyang North Korea                 0.3          6.0
#
#                        Domestic_Beer_Market(0.5L)  \
# city      country
# Pyongyang North Korea                         NaN
#
# ...

# %%
# Find top 10 least expensive places that sell milk
cost_of_living.Milk.sort_values().head(10)
# Out:
# city            country
# Pyongyang       North Korea    0.26
# Kars            Turkey         0.32
# Sidi Bel Abbes  Algeria        0.32
# Mpigi           Uganda         0.32
# Fort Portal     Uganda         0.32
# Nallacheruvu    India          0.34
# Jendouba        Tunisia        0.34
# Sakiet ez Zit   Tunisia        0.35
# Toba Tek Singh  Pakistan       0.36
# Gojra           Pakistan       0.36
# Name: Milk, dtype: float64

# %%
least_milk_values = [0.26, 0.32, 0.32, 0.32, 0.32]
least_milk_locations = ['Pyongyang, North Korea', 'Kars, Turkey', 'Sidi Bel Abbes, Algeria', 'Mpigi, Uganda', 'Fort Portal, Uganda']

# %%
# Create bar graph
plt.style.use('dark_background')

plt.title('Top 5 Least Expensive Milk Worldwide')

bar_width = 0.7

plt.bar(least_milk_locations, least_milk_values, width=bar_width)
plt.bar('Average', milk_average, width=bar_width)
plt.xticks(rotation=45)
 

plt.xlabel('Country')
plt.ylabel('Price in USD')

plt.show()

# %%
# Find top 10 most expensive places that sell milk
cost_of_living.Milk.sort_values(ascending=False).head(10)
# Out:
# city           country
# Beirut         Lebanon                     6.81
# Yaren          Nauru                       6.71
# Grand Turk     Turks And Caicos Islands    6.00
# Vreed-en-Hoop  Guyana                      5.73
# Roseau         Dominica                    5.00
# Williams Lake  Canada                      4.83
# As Sib         Oman                        4.67
# Turkmenabat    Turkmenistan                4.27
# Hamilton       Bermuda                     4.24
# Ashgabat       Turkmenistan                4.20
# Name: Milk, dtype: float64

# %%
most_milk_values = [6.81, 6.71, 6.00, 5.73, 5.00]
most_milk_locations = ['Beirut, Lebanon', 'Yaren, Nauru', 'Grand Turk, Turks And Caicos Islands', 'Vreed-en-Hoop, Guyana', 'Roseau, Dominica']

# %%
# Create bar graph
plt.style.use('dark_background')

plt.title('Top 5 Most Expensive Milk Worldwide')

bar_width = 0.7

plt.bar(most_milk_locations, most_milk_values, width=bar_width)
plt.bar('Average', milk_average, width=bar_width)
plt.xticks(rotation=45)
 

plt.xlabel('Country')
plt.ylabel('Price in USD')

plt.show()

# %%
# Find average of cheese column
cheese_len = cost_of_living.Cheese.count()
cheese_sum = cost_of_living.Cheese.sum()
cheese_average = round(cheese_sum/cheese_len, 2)
print(cheese_average)
# Out:
# 9.33

# %%
# Find max and min values in cheese column
max_cheese = cost_of_living.Cheese.max()
min_cheese = cost_of_living.Cheese.min()
print(max_cheese)
print(min_cheese)
# Out:
# 48.47
# 0.9

# %%
# Find max value in dataframe
cost_of_living[cost_of_living.Cheese == 48.47]
# Out:
#                     No.  Meal  Meal_For_2  McDonalds_Meal  \
# city      country
# Bac Ninh  Vietnam   847  1.89       12.12            3.23
# Hai Duong Vietnam   870   NaN         NaN             NaN
# Bac Giang Vietnam  2853  2.83       16.16             NaN
#
#                    Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city      country
# Bac Ninh  Vietnam                       NaN                       1.21
# Hai Duong Vietnam                       NaN                        NaN
# Bac Giang Vietnam                      0.32                       0.97
#
#                    Cappuccino  Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  \
# city      country                                                   ...
# Bac Ninh  Vietnam        1.41        0.48               0.36  1.21  ...
# Hai Duong Vietnam         NaN         NaN                NaN  1.21  ...
# Bac Giang Vietnam        1.01        0.36               0.16  1.21  ...
#
# ...

# %%
# Find min value in dataframe
cost_of_living[cost_of_living.Cheese == 0.9]
# Out:
#                No.  Meal  Meal_For_2  McDonalds_Meal  \
# city  country
# Ikeja Nigeria  611  1.13       11.26            3.38
#
#                Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city  country
# Ikeja Nigeria                      0.79                       0.96
#
#                Cappuccino  Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  Oranges  \
# city  country                                                   ...
# Ikeja Nigeria        0.45        0.23               0.15  0.79  ...     0.45
#
#                Tomato  Potato  Onion  Lettuce  Water_Market(1.5L)  \
# city  country
# Ikeja Nigeria    0.68    3.38   2.03     0.68                0.34
#
#                Wine_Market  Domestic_Beer_Market(0.5L)  \
# city  country
# Ikeja Nigeria         1.89                        0.39
#
#                Imported_Beer_Market(0.33L)  Cigarettes
# city  country
# Ikeja Nigeria                         0.62        0.68
#
# [1 rows x 28 columns]

# %%
# Find top 10 least expensive cities that sell cheese
cost_of_living.Cheese.sort_values().head(10)
# Out:
# city     country
# Ikeja    Nigeria     0.90
# Bello    Colombia    1.22
# Cartago  Colombia    1.22
# Luxor    Egypt       1.28
# Abnub    Egypt       1.28
# Popayan  Colombia    1.32
# Makurdi  Nigeria     1.35
# Minna    Nigeria     1.35
# Ilorin   Nigeria     1.35
# Titel    Serbia      1.40
# Name: Cheese, dtype: float64

# %%
least_cheese_values = [0.90, 1.22, 1.22, 1.28, 1.28]
least_cheese_locations = ['Ikeja, Nigeria', 'Bello, Colombia', 'Cartago, Colombia', 'Luxos, Egypt', 'Abnub, Egypt']

# %%
# Create bar graph
plt.style.use('dark_background')

plt.title('Top 5 Least Expensive Cheese Worldwide')

bar_width = 0.7

plt.bar(least_cheese_locations, least_cheese_values, width=bar_width)
plt.bar('Average', cheese_average, width=bar_width)
plt.xticks(rotation=45)
 

plt.xlabel('Country')
plt.ylabel('Price in USD')

plt.show()

# %%
# Find top 10 most expensive cities that sell cheese
cost_of_living.Cheese.sort_values(ascending=False).head(10)
# Out:
# city        country
# Bac Ninh    Vietnam        48.47
# Hai Duong   Vietnam        48.47
# Bac Giang   Vietnam        48.47
# Utsunomiya  Japan          43.31
# Modling     Austria        41.55
# Keelung     Taiwan         39.57
# Solothurn   Switzerland    38.04
# Aomori      Japan          37.54
# Bastia      France         37.39
# Schwyz      Switzerland    36.99
# Name: Cheese, dtype: float64

# %%
most_cheese_values = [48.47, 48.47, 48.47, 43.31, 41.55]
most_cheese_locations = ['Bac Ninh, Vietnam', 'Hai Duong, Vietnam', 'Bac Giang, Vietnam', 'Utsunomiya, Japan', 'Modling, Austria']

# %%
# Create bar graph
plt.style.use('dark_background')

plt.title('Top 5 Most Expensive Cheese Worldwide')

bar_width = 0.7

plt.bar(most_cheese_locations, most_cheese_values, width=bar_width)
plt.bar('Average', cheese_average, width=bar_width)
plt.xticks(rotation=45)
 

plt.xlabel('Country')
plt.ylabel('Price in USD')

plt.show()

# %%
# Find average of chicken column
chicken_len = cost_of_living.Chicken_Fillets.count()
chicken_sum = cost_of_living.Chicken_Fillets.sum()
chicken_average = round(chicken_sum/chicken_len, 2)
print(chicken_average)
# Out:
# 7.17

# %%
# Find max and min values in chicken fillet column
max_chicken = cost_of_living.Chicken_Fillets.max()
min_chicken = cost_of_living.Chicken_Fillets.min()
print(max_chicken)
print(min_chicken)
# Out:
# 44.09
# 1.17

# %%
# Find max chicken value in the dataframe
cost_of_living[cost_of_living.Chicken_Fillets == 44.09]
# Out:
#                                     No.  Meal  Meal_For_2  McDonalds_Meal  \
# city                country
# South Miami Heights United States  3039  50.0        25.0            11.5
# Gallup              United States  4457   NaN        60.0            15.0
#
#                                    Domestic_Beer_Rest(0.5L)  \
# city                country
# South Miami Heights United States                      10.0
# Gallup              United States                       NaN
#
#                                    Imported_Beer_Rest(0.33L)  Cappuccino  \
# city                country
# South Miami Heights United States                       15.0         6.0
# Gallup              United States                        NaN        10.0
#
#                                    Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  \
# city                country                                             ...
# South Miami Heights United States         3.0                1.5  1.19  ...
# ...

# %%
# Find min chicken value in the dataframe
cost_of_living[cost_of_living.Chicken_Fillets == 1.17]
# Out:
#                        No.  Meal  Meal_For_2  McDonalds_Meal  \
# city      country
# Narsingdi Bangladesh  1749   1.4        5.62             NaN
#
#                       Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city      country
# Narsingdi Bangladesh                       NaN                        NaN
#
#                       Cappuccino  Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  \
# city      country                                                      ...
# Narsingdi Bangladesh        2.34        0.33               0.07  0.66  ...
#
#                       Oranges  Tomato  Potato  Onion  Lettuce  \
# city      country
# Narsingdi Bangladesh     1.26    0.66    0.28   0.54      NaN
#
#                       Water_Market(1.5L)  Wine_Market  \
# city      country
# Narsingdi Bangladesh                0.23          NaN
#
#                       Domestic_Beer_Market(0.5L)  Imported_Beer_Market(0.33L)  \
# city      country
# ...

# %%
# Find top 10 least expensive cities that sell chicken
cost_of_living.Chicken_Fillets.sort_values().head(10)
# Out:
# city             country
# Narsingdi        Bangladesh    1.17
# Pabna            Bangladesh    1.22
# Puri             India         1.22
# Tataouine        Tunisia       1.24
# Kairouan         Tunisia       1.24
# Saint Ann's Bay  Jamaica       1.30
# Mandeville       Jamaica       1.30
# Andimeshk        Iran          1.30
# Malayer          Iran          1.30
# Tangail          Bangladesh    1.31
# Name: Chicken_Fillets, dtype: float64

# %%
least_chicken_values = [1.17, 1.22, 1.22, 1.24, 1.24]
least_chicken_locations = ['Narsingdi, Bangladesh', 'Pabna, Bangladesh', 'Puri, India', 'Tataouine, Tunisia', 'Kairouan, Tunisia']

# %%
# Create bar graph
plt.style.use('dark_background')

plt.title('Top 5 Least Expensive Chicken Fillets Worldwide')

bar_width = 0.7

plt.bar(least_chicken_locations, least_chicken_values, width=bar_width)
plt.bar('Average', chicken_average, width=bar_width)
plt.xticks(rotation=45)
 

plt.xlabel('Country')
plt.ylabel('Price in USD')

plt.show()

# %%
# Find top 10 most expensive cities that sell chicken
cost_of_living.Chicken_Fillets.sort_values(ascending=False).head(10)
# Out:
# city                 country
# South Miami Heights  United States    44.09
# Gallup               United States    44.09
# Meilen               Switzerland      41.21
# Affoltern am Albis   Switzerland      36.99
# Opfikon              Switzerland      35.93
# Vernier              Switzerland      35.75
# Saratoga Springs     United States    35.25
# Allschwil            Switzerland      34.87
# Webb City            United States    34.02
# San Dimas            United States    33.07
# Name: Chicken_Fillets, dtype: float64

# %%
most_chicken_values = [44.09, 44.09, 41.21, 36.99, 35.93]
most_chicken_locations = ['South Miami Heights, United States', 'Gallup, United States', 'Meilen, Switzerland', 'Affoltern am Albis, Switzerland', 'Opfikon, Switzerland']

# %%
# Create bar graph
plt.style.use('dark_background')

plt.title('Top 5 Most Expensive Chicken Fillets Worldwide')

bar_width = 0.7

plt.bar(most_chicken_locations, most_chicken_values, width=bar_width)
plt.bar('Average', chicken_average, width=bar_width)
plt.xticks(rotation=45)
 

plt.xlabel('Country')
plt.ylabel('Price in USD')

plt.show()

# %%
# Find max and min values of bread column
max_bread = cost_of_living.Bread.max()
min_bread = cost_of_living.Bread.min()
print(max_bread)
print(min_bread)
# Out:
# 8.81
# 0.05

# %%
# Find max bread value in dataframe
cost_of_living[cost_of_living.Bread == 8.81]
# Out:
#                                    No.  Meal  Meal_For_2  McDonalds_Meal  \
# city               country
# Plantation         United States  3518   NaN         NaN             NaN
# Vandenberg Village United States  4794  15.0        40.0             9.0
#
#                                   Domestic_Beer_Rest(0.5L)  \
# city               country
# Plantation         United States                       NaN
# Vandenberg Village United States                       7.0
#
#                                   Imported_Beer_Rest(0.33L)  Cappuccino  \
# city               country
# Plantation         United States                        NaN         NaN
# Vandenberg Village United States                        5.0         5.0
#
#                                   Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  \
# city               country                                             ...
# Plantation         United States         NaN                NaN  1.26  ...
# ...

# %%
# Find min bread value in dataframe
cost_of_living[cost_of_living.Bread == 0.05]
# Out:
#                   No.  Meal  Meal_For_2  McDonalds_Meal  \
# city    country
# Djemmal Tunisia  3689  1.97         NaN            2.96
#
#                  Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city    country
# Djemmal Tunisia                      0.99                       0.99
#
#                  Cappuccino  Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  \
# city    country                                                   ...
# Djemmal Tunisia        0.49        0.37               0.22  0.39  ...
#
#                  Oranges  Tomato  Potato  Onion  Lettuce  Water_Market(1.5L)  \
# city    country
# Djemmal Tunisia     0.93    0.31    0.31   0.31     0.31                0.31
#
#                  Wine_Market  Domestic_Beer_Market(0.5L)  \
# city    country
# Djemmal Tunisia         1.54                        0.62
#
#                  Imported_Beer_Market(0.33L)  Cigarettes
# city    country
# Djemmal Tunisia                         0.77        2.01
#
# ...

# %%
# Find the top 10 least expensive places that sell bread
cost_of_living.Bread.sort_values().head(10)
# Out:
# city       country
# Djemmal    Tunisia    0.05
# Mascara    Algeria    0.07
# Adrar      Algeria    0.07
# Tindouf    Algeria    0.07
# Laghouat   Algeria    0.08
# Gafsa      Tunisia    0.08
# Jendouba   Tunisia    0.08
# Nabeul     Tunisia    0.08
# Hammamet   Tunisia    0.08
# Kasserine  Tunisia    0.08
# Name: Bread, dtype: float64

# %%
# Find the top 10 most expensive places that sell bread
cost_of_living.Bread.sort_values(ascending=False).head(10)
# Out:
# city                country
# Plantation          United States    8.81
# Vandenberg Village  United States    8.81
# Moses Lake          United States    7.71
# California          United States    7.71
# Odawara             Japan            7.22
# Royal Oak           United States    7.17
# Hamilton            Bermuda          6.85
# Klamath Falls       United States    6.61
# Bethel Park         United States    6.61
# New Haven           United States    6.61
# Name: Bread, dtype: float64

# %%
# Find max and min values in eggs column
max_eggs = cost_of_living.Eggs.max()
min_eggs = cost_of_living.Eggs.min()
print(max_eggs)
print(min_eggs)
# Out:
# 9.65
# 0.1

# %%
# Find max eggs value in dataframe
cost_of_living[cost_of_living.Eggs == 9.65]
# Out:
#                         No.   Meal  Meal_For_2  McDonalds_Meal  \
# city      country
# Solothurn Switzerland  3227  22.72       92.47           17.44
#
#                        Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city      country
# Solothurn Switzerland                      6.34                       6.34
#
#                        Cappuccino  Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  \
# city      country                                                       ...
# Solothurn Switzerland        5.55        3.43               3.43  1.93  ...
#
#                        Oranges  Tomato  Potato  Onion  Lettuce  \
# city      country
# Solothurn Switzerland      4.7     3.7    1.27   1.37     2.64
#
#                        Water_Market(1.5L)  Wine_Market  \
# city      country
# Solothurn Switzerland                1.02        11.62
#
#                        Domestic_Beer_Market(0.5L)  \
# city      country
# Solothurn Switzerland                        2.33
#
# ...

# %%
# Find min eggs value in dataframe
cost_of_living[cost_of_living.Eggs == 0.1]
# Out:
#                   No.  Meal  Meal_For_2  McDonalds_Meal  \
# city    country
# Konotop Ukraine  2475  3.79        8.12            2.92
#
#                  Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city    country
# Konotop Ukraine                      0.72                       1.08
#
#                  Cappuccino  Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  \
# city    country                                                   ...
# Konotop Ukraine        0.68        0.51               0.27  0.54  ...
#
#                  Oranges  Tomato  Potato  Onion  Lettuce  Water_Market(1.5L)  \
# city    country
# Konotop Ukraine     0.68    2.07    0.34   0.41     0.54                0.44
#
#                  Wine_Market  Domestic_Beer_Market(0.5L)  \
# city    country
# Konotop Ukraine         4.87                        0.81
#
#                  Imported_Beer_Market(0.33L)  Cigarettes
# city    country
# Konotop Ukraine                         0.81        1.89
#
# ...

# %%
# Find top 10 least expensive cities that sell eggs
cost_of_living.Eggs.sort_values().head(10)
# Out:
# city          country
# Konotop       Ukraine      0.10
# Gafsa         Tunisia      0.37
# Pithapuram    India        0.51
# Kutahya       Turkey       0.54
# Sanandaj      Iran         0.57
# Matale        Sri Lanka    0.59
# Malayer       Iran         0.60
# Andimeshk     Iran         0.60
# Moratuwa      Sri Lanka    0.65
# Nuwara Eliya  Sri Lanka    0.65
# Name: Eggs, dtype: float64

# %%
# Find top 10 most expensive cities that sell eggs
cost_of_living.Eggs.sort_values(ascending=False).head(10)
# Out:
# city                country
# Solothurn           Switzerland      9.65
# Lachen              Switzerland      8.45
# Bellinzona          Switzerland      8.11
# Madinat Hamad       Bahrain          7.96
# Fribourg            Switzerland      7.78
# Affoltern am Albis  Switzerland      7.61
# Aigle               Switzerland      7.61
# Schaan              Liechtenstein    7.37
# Triesen             Liechtenstein    7.37
# Ruggell             Liechtenstein    7.37
# Name: Eggs, dtype: float64

# %%
# Find max and min values in Beef column
max_beef = cost_of_living.Beef.max()
min_beef = cost_of_living.Beef.min()
print(max_beef)
print(min_beef)
# Out:
# 95.11
# 1.43

# %%
# Find max beef value in dataframe
cost_of_living[cost_of_living.Beef == 95.11]
# Out:
#                     No.   Meal  Meal_For_2  McDonalds_Meal  \
# city  country
# Aarau Switzerland  3179  23.25       84.54           15.85
#
#                    Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city  country
# Aarau Switzerland                      6.08                       5.28
#
#                    Cappuccino  Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  \
# city  country                                                       ...
# Aarau Switzerland        4.57        3.59               3.59  1.87  ...
#
#                    Oranges  Tomato  Potato  Onion  Lettuce  \
# city  country
# Aarau Switzerland     5.23    1.96    2.75    NaN      NaN
#
#                    Water_Market(1.5L)  Wine_Market  \
# city  country
# Aarau Switzerland                 NaN        12.15
#
#                    Domestic_Beer_Market(0.5L)  Imported_Beer_Market(0.33L)  \
# city  country
# Aarau Switzerland                         1.8                         2.64
#
# ...

# %%
# Find min beef value in dataframe
cost_of_living[cost_of_living.Beef == 1.43]
# Out:
#                      No.  Meal  Meal_For_2  McDonalds_Meal  \
# city      country
# Soledad   Colombia   670  3.06         NaN            4.08
# Sincelejo Colombia  1313  3.06        16.3            4.08
#
#                     Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city      country
# Soledad   Colombia                      3.06                       0.82
# Sincelejo Colombia                      1.02                       0.82
#
#                     Cappuccino  Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  \
# city      country                                                    ...
# Soledad   Colombia        1.63        0.61                NaN   NaN  ...
# Sincelejo Colombia        0.98        0.53                0.4   0.7  ...
#
#                     Oranges  Tomato  Potato  Onion  Lettuce  \
# city      country
# Soledad   Colombia      NaN     NaN    0.41   0.22      0.2
# Sincelejo Colombia     0.98    0.91    0.41   0.22      0.2
#
# ...

# %%
# Find top 10 least expensive places that sell beef
cost_of_living.Beef.sort_values().head(10)
# Out:
# city            country
# Soledad         Colombia    1.43
# Sincelejo       Colombia    1.43
# Mbeya           Tanzania    1.72
# Kumasi          Ghana       1.76
# Sambalpur       India       1.84
# Krishnapur      India       1.84
# Mandi Burewala  Pakistan    2.00
# Loja            Ecuador     2.00
# Osogbo          Nigeria     2.10
# Ondo            Nigeria     2.10
# Name: Beef, dtype: float64

# %%
# Find top 10 most expensive cities that sell beef
cost_of_living.Beef.sort_values(ascending=False).head(10)
# Out:
# city                country
# Aarau               Switzerland    95.11
# Schwyz              Switzerland    89.83
# Lucerne             Switzerland    72.21
# Beirut              Lebanon        68.01
# Dubendorf           Switzerland    66.22
# Basel               Switzerland    66.12
# Aigle               Switzerland    63.41
# Affoltern am Albis  Switzerland    63.41
# Glarus              Switzerland    62.35
# Lausanne            Switzerland    59.31
# Name: Beef, dtype: float64

# %%
# Find max and min values in market water 1.5L 
max_water = cost_of_living["Water_Market(1.5L)"].max()
min_water = cost_of_living["Water_Market(1.5L)"].min()
print(max_water)
print(min_water)
# Out:
# 5.0
# 0.11

# %%
# Find max value of water in the dataframe
cost_of_living[cost_of_living['Water_Market(1.5L)'] == 5.0]
# Out:
#                                 No.  Meal  Meal_For_2  McDonalds_Meal  \
# city            country
# East Orange     United States  2789  25.0        45.0            9.00
# North Brunswick United States  4075  22.5        60.0            6.99
# Wrightsville    United States  4851  25.0        45.0           11.00
#
#                                Domestic_Beer_Rest(0.5L)  \
# city            country
# East Orange     United States                       5.0
# North Brunswick United States                       NaN
# Wrightsville    United States                       5.0
#
#                                Imported_Beer_Rest(0.33L)  Cappuccino  \
# city            country
# East Orange     United States                        6.0         3.5
# North Brunswick United States                        3.0         2.0
# Wrightsville    United States                        8.0         3.5
#
#                                Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  \
# ...

# %%
# Find min value of water in the dataframe
cost_of_living[cost_of_living['Water_Market(1.5L)'] == 0.11]
# Out:
#                       No.  Meal  Meal_For_2  McDonalds_Meal  \
# city    country
# Aksaray Turkey       2739  1.54       10.73            2.95
# Gardez  Afghanistan  2743   NaN         NaN             NaN
#
#                      Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city    country
# Aksaray Turkey                            1.5                       2.15
# Gardez  Afghanistan                       NaN                        NaN
#
#                      Cappuccino  Coke/Pepsi  Water_Rest(0.33L)  Milk  ...  \
# city    country                                                       ...
# Aksaray Turkey             1.35        0.38               0.11  0.71  ...
# Gardez  Afghanistan         NaN         NaN                NaN  0.67  ...
#
#                      Oranges  Tomato  Potato  Onion  Lettuce  \
# city    country
# Aksaray Turkey          0.47    0.74    0.39   0.27     0.53
# Gardez  Afghanistan     0.89    0.44    0.33   0.33      NaN
#
# ...

# %%
# Find top 10 least expensive places that sell water in the market at 1.5L
cost_of_living["Water_Market(1.5L)"].sort_values().head(10)
# Out:
# city            country
# Gardez          Afghanistan    0.11
# Aksaray         Turkey         0.11
# Agri            Turkey         0.13
# Nysa            Poland         0.13
# Hassi Messaoud  Algeria        0.14
# Andimeshk       Iran           0.15
# Jendouba        Tunisia        0.15
# Al Bayda'       Libya          0.15
# Malayer         Iran           0.15
# Tulsipur        Nepal          0.15
# Name: Water_Market(1.5L), dtype: float64

# %%
# Find top 10 most expensive places that sell water in the market at 1.5L
cost_of_living["Water_Market(1.5L)"].sort_values(ascending=False).head(10)
# Out:
# city             country
# North Brunswick  United States    5.00
# East Orange      United States    5.00
# Wrightsville     United States    5.00
# Cairns           Australia        4.69
# Port Douglas     Australia        4.69
# Ocean Springs    United States    4.50
# Clemson          United States    4.16
# Thornton         United States    4.12
# Iqaluit          Canada           4.03
# Margaret River   Australia        4.02
# Name: Water_Market(1.5L), dtype: float64

# %%
# Dropping all rows with NaN values
cost_of_living.dropna(inplace=True)
cost_of_living
# Out:
#                            No.   Meal  Meal_For_2  McDonalds_Meal  \
# city         country
# Delhi        India           0   4.90       22.04            4.28
# Shanghai     China           1   5.59       40.51            5.59
# Jakarta      Indonesia       2   2.54       22.25            3.50
# Manila       Philippines     3   3.54       27.40            3.54
# Seoul        South Korea     4   7.16       52.77            6.03
# ...                        ...    ...         ...             ...
# Mackay       Australia    4859  13.41       93.89            7.71
# Tirupati     India        4863   2.45        9.18            4.28
# Port Douglas Australia    4864  15.76       66.39           10.06
# Rockhampton  Australia    4865  13.41       63.71            8.05
# Egilsstadhir Iceland      4867  17.30       70.61            8.47
#
#                           Domestic_Beer_Rest(0.5L)  Imported_Beer_Rest(0.33L)  \
# city         country
# ...

# %%
# Function that will add all the column values together
def sum_columns(row):
  goods_sum = row.Meal + row.Meal_For_2 + row.McDonalds_Meal + row["Domestic_Beer_Rest(0.5L)"] + row['Imported_Beer_Rest(0.33L)'] + row.Cappuccino + row['Coke/Pepsi'] + row['Water_Rest(0.33L)'] + row.Milk + row.Rice + row.Eggs + row.Cheese + row.Chicken_Fillets + row.Beef + row.Apple + row.Bananas + row.Oranges + row.Tomato + row.Potato + row.Onion + row.Lettuce + row['Water_Market(1.5L)'] + row.Wine_Market + row['Domestic_Beer_Market(0.5L)'] + row['Imported_Beer_Market(0.33L)'] + row.Cigarettes
  return goods_sum

cost_of_living['goods_sum'] = cost_of_living.apply(sum_columns, axis=1)

cost_of_living['goods_sum']
# Out:
# city          country
# Delhi         India           79.58
# Shanghai      China          134.23
# Jakarta       Indonesia       99.55
# Manila        Philippines     90.27
# Seoul         South Korea    208.01
#                               ...
# Mackay        Australia      233.35
# Tirupati      India           65.01
# Port Douglas  Australia      239.24
# Rockhampton   Australia      193.78
# Egilsstadhir  Iceland        209.78
# Name: goods_sum, Length: 3366, dtype: float64

# %%
# Calculate the average of cost of goods
goods_len = cost_of_living.goods_sum.count()
goods_sum = cost_of_living.goods_sum.sum()

goods_average = round(goods_sum/goods_len, 2)
print(goods_average)
# Out:
# 138.75

# %%
# Sorts goods sum column to show least expensive cities
cost_of_living.goods_sum.sort_values().head(5)
# Out:
# city             country
# Sahiwal          Pakistan    32.70
# Dera Ghazi Khan  Pakistan    32.88
# Faisalabad       Pakistan    34.91
# Bahawalpur       Pakistan    37.60
# Ho               Ghana       38.44
# Name: goods_sum, dtype: float64

# %%
goods_least_values = [32.70, 32.88, 34.91, 37.60, 38.44]
goods_least_locations = ['Sahiwal, Pakistan', 'Dera Ghazi Khan, Pakistan', 'Daisalabad, Pakistan', 'Bahawalpur, Pakistan', 'Ho, Ghana']

# %%
# Create bar graph
plt.style.use('dark_background')

plt.title('Top 5 Least Expensive Amount of Goods')

bar_width = 0.7

plt.bar(goods_least_locations, goods_least_values, width=bar_width)
plt.bar('Average', goods_average, width=bar_width)
plt.xticks(rotation=45)
 

plt.xlabel('Country')
plt.ylabel('Price in USD')

plt.show()

# %%
# Sorts goods sum column to show most expensive cities
cost_of_living.goods_sum.sort_values(ascending=False).head(5)
# Out:
# city      country
# Hamilton  Bermuda         416.71
# Meilen    Switzerland     390.09
# Basel     Switzerland     388.04
# Kaka      Turkmenistan    385.80
# Ashgabat  Turkmenistan    385.78
# Name: goods_sum, dtype: float64

# %%
goods_most_values = [416.71, 390.09, 388.04, 385.80, 385.78]
goods_most_locations = ['Hamilton, Bermuda', 'Meilen, Switzerland', 'Basel, Switzerland', 'Kaka, Turmenistan', 'Ashgabat, Turmenistan']

# %%
# Create bar graph
plt.style.use('dark_background')

plt.title('Top 5 Most Expensive Amount of Goods')

bar_width = 0.7

plt.bar(goods_most_locations, goods_most_values, width=bar_width)
plt.bar('Average', goods_average, width=bar_width)
plt.xticks(rotation=45)
 

plt.xlabel('Country')
plt.ylabel('Price in USD')

plt.show()
